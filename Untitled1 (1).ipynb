# %%
import requests
from datetime import datetime

api_key = 'f7c5c50711675d17f6832a86472eb3aa'
location = input("Enter the city name :")


complete_api_link = "https://api.openweathermap.org/data/2.5/weather?q="+location+"&applid="+api_key
api_link = requests.get(complete_api_link)
api_data = api_link.json()

# %% [markdown]
# Create variables to store and display data

# %%
temp_city = ((api_data['main']['temp']) - 273.15)
weather_desc = api_data['weather'][0]['discription']
hndt = api_data['main']['humidity']
wind_spd = api_data['wind']['speed']
data_time = datatime.now().strftime("%d %b %Y | %I:%M:%S %P")

print("---------------------------------------------------------------")
print("Weather Stats for = {} || {}".format(location.upper(), data_time))
print("---------------------------------------------------------------")


print("Current temperature is: {:.2f") deg C".format(temp_city))
print("Current weather desc  :",weather_desc)
print("Current Humidity      :",hmdt, '%')
print("Current wind speed    :",wind_spd ,'kmph')
